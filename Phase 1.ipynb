# %% [markdown]
# # Crimes in india (2001-2012)

# %% [markdown]
# ### Data Collection/preparation part.
#
# Note:
#
# collected data from (wiki, google, etc) link is mensioned below from where data is being collected.
#
# Data collected manually.

# %% [raw]
# Dataset includes,
#
# The population of each state.
#
# Literacy Rate in each state
#
# Area of each state
#
#
# Created a new file and kept the above-collected data seperately

# %%
import pandas as pd

# %%
df=pd.read_csv("Cumulative Dataset of Crimes in india.csv")
df
# Out:
#               STATE/UT  YEAR  POPULATION  LITERACY RATE  AREA (in sq. km)  \
# 0       ANDHRA PRADESH  2001    76210007          60.47            275045
# 1    ARUNACHAL PRADESH  2001     1097968          54.34             83743
# 2                ASSAM  2001    26655528          63.25             78438
# 3                BIHAR  2001    82998509          47.00             94163
# 4         CHHATTISGARH  2001    20733232          64.66            135191
# ..                 ...   ...         ...            ...               ...
# 403         CHANDIGARH  2012     1144839          86.05               114
# 404       D & N HAVELI  2012      259148            NaN               491
# 405        DAMAN & DIU  2012      191924            NaN               112
# 406        LAKSHADWEEP  2012       74578            NaN                32
# 407         PUDUCHERRY  2012     1148900            NaN               479
#
#      MURDER  ATTEMPT TO MURDER  CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  \
# ...

# %% [markdown]
# *Data for the population,area of each state and literacy rate of each state have been collected from the different websites manually.
#
# *The data was available for the year #2001 and #2012 for population, area and literacy rate of each state.
#
# The 15th official census in India was calculated in the year 2011. So, necassary calculations and assumptions were made in order to achive the data for the year #2011  & #2012.
#
# Several websites were used in order to fetch the data for the same. Some of them are:-
#
#
# https://www.census2011.co.in/
# https://mospi.gov.in/sites/default/files/reports_and_publication/cso_research_and_publication_unit/Statistical_Abstract%20_India/2006/sa_06_area_population.pdf
# https://en.wikipedia.org/wiki/List_of_states_in_India_by_past_population
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_area
# https://en.wikipedia.org/wiki/List_of_Indian_states_and_union_territories_by_literacy_rate
# https://socialjustice.gov.in/common/76669
# http://cyberjournalist.org.in/census/cenindia.html
# https://www.indiastat.com/specimen-tables/geographical-data
# https://www.wbhealth.gov.in/other_files/2007/14_5.html
# https://en.wikipedia.org/wiki/List_of_states_and_union_territories_of_India_by_population
